# %%
import pandas as pd
import numpy as np

# %%
cd
# Out:
# C:\Users\cvr

# %%
import pandas as pd
import numpy as np
hd=pd.read_csv('wine_data.csv')

# %%
hd.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0           11.6             0.580         0.66            2.20      0.074
# 1           10.4             0.610         0.49            2.10      0.200
# 2            7.4             1.185         0.00            4.25      0.097
# 3           10.4             0.440         0.42            1.50      0.145
# 4            8.3             1.020         0.02            3.40      0.084
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 10.0                  47.0  1.00080  3.25       0.57
# 1                  5.0                  16.0  0.99940  3.16       0.63
# 2                  5.0                  14.0  0.99660  3.63       0.54
# 3                 34.0                  48.0  0.99832  3.38       0.86
# 4                  6.0                  11.0  0.99892  3.48       0.49
#
#    alcohol  quality
# 0      9.0        3
# 1      8.4        3
# 2     10.7        3
# ...

# %%
hd.tail()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 20995            9.7              1.02         0.91            50.0
# 20996           10.2              0.61         0.88            53.8
# 20997           13.4              0.46         1.04            52.1
# 20998            6.6              1.03         1.09            25.3
# 20999            9.3              0.93         1.32            33.6
#
#        chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# 20995      0.412                114.6                 181.7  1.02085  3.30
# 20996      0.250                 62.4                 204.7  1.02776  3.52
# 20997      0.449                 63.0                 273.5  1.02618  2.89
# 20998      0.138                179.8                 295.0  1.02476  2.94
# 20999      0.412                128.7                 290.1  1.02182  3.16
#
#        sulphates  alcohol  quality
# 20995       0.89     12.0        9
# ...

# %%
hd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21000 entries, 0 to 20999
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         21000 non-null  float64
#  1   volatile_acidity      21000 non-null  float64
#  2   citric_acid           21000 non-null  float64
#  3   residual_sugar        21000 non-null  float64
#  4   chlorides             21000 non-null  float64
#  5   free_sulfur_dioxide   21000 non-null  float64
#  6   total_sulfur_dioxide  21000 non-null  float64
#  7   density               21000 non-null  float64
#  8   pH                    21000 non-null  float64
#  9   sulphates             21000 non-null  float64
#  10  alcohol               21000 non-null  float64
#  11  quality               21000 non-null  int64
# dtypes: float64(11), int64(1)
# memory usage: 1.9 MB

# %%
hd.shape
# Out:
# (21000, 12)

# %%
hd.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
hd.isnull()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0              False             False        False           False
# 1              False             False        False           False
# 2              False             False        False           False
# 3              False             False        False           False
# 4              False             False        False           False
# ...              ...               ...          ...             ...
# 20995          False             False        False           False
# 20996          False             False        False           False
# 20997          False             False        False           False
# 20998          False             False        False           False
# 20999          False             False        False           False
#
#        chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density     pH  \
# ...

# %%
hd.isnull().sum()
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
hd.iloc[0]
# Out:
# fixed_acidity           11.6000
# volatile_acidity         0.5800
# citric_acid              0.6600
# residual_sugar           2.2000
# chlorides                0.0740
# free_sulfur_dioxide     10.0000
# total_sulfur_dioxide    47.0000
# density                  1.0008
# pH                       3.2500
# sulphates                0.5700
# alcohol                  9.0000
# quality                  3.0000
# Name: 0, dtype: float64

# %%
hd.pH.unique()
# Out:
# array([3.25, 3.16, 3.63, 3.38, 3.48, 3.5 , 3.32, 3.31, 3.4 , 3.55, 3.02,
#        3.53, 3.23, 3.24, 2.89, 2.87, 3.2 , 3.04, 3.14, 2.93, 3.05, 3.42,
#        2.9 , 3.37, 3.44, 3.01, 3.03, 2.98, 3.08, 3.15, 3.1 , 3.58, 2.96,
#        2.91, 2.85, 2.99, 3.21, 3.39, 3.11, 3.34, 3.47, 2.78, 2.94, 3.19,
#        3.09, 3.18, 3.17, 2.95, 3.45, 3.29, 3.65, 3.22, 3.13, 3.51, 3.26,
#        3.56, 2.92, 3.07, 3.33, 2.86, 3.28, 3.12, 3.41, 2.97, 3.  , 3.3 ,
#        3.46, 3.27, 2.88, 2.84, 3.06, 3.35, 3.36, 3.62, 2.81, 3.6 , 3.57,
#        2.8 , 3.43, 3.52, 3.59, 2.83, 3.68, 2.79, 3.61, 3.54, 3.49, 2.82,
#        3.72, 3.9 , 3.75, 2.74, 3.66, 2.75, 3.64, 2.77, 3.71, 3.67, 3.74,
#        3.69, 3.77, 3.79, 3.81, 3.85, 3.7 , 3.78, 4.01, 2.72, 3.8 , 3.76,
#        3.82, 3.73])

# %%
hd.pH.drop_duplicates()
# Out:
# 0        3.25
# 1        3.16
# 2        3.63
# 3        3.38
# 4        3.48
#          ...
# 10453    2.72
# 10513    3.80
# 11590    3.76
# 12434    3.82
# 13250    3.73
# Name: pH, Length: 112, dtype: float64

# %%
hd.drop_duplicates()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0               11.6             0.580         0.66            2.20
# 1               10.4             0.610         0.49            2.10
# 2                7.4             1.185         0.00            4.25
# 3               10.4             0.440         0.42            1.50
# 4                8.3             1.020         0.02            3.40
# ...              ...               ...          ...             ...
# 20985           10.3             1.080         0.53           50.80
# 20987           11.4             0.900         0.64           51.20
# 20988           11.8             1.100         0.84           46.50
# 20993           13.0             0.580         1.22           52.80
# 20994           12.8             0.850         1.12           44.90
#
#        chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# ...

# %%
hd.describe()
# Out:
#        fixed_acidity  volatile_acidity   citric_acid  residual_sugar  \
# count   21000.000000      21000.000000  21000.000000    21000.000000
# mean        9.797079          0.774796      0.793870       31.289348
# std         2.413919          0.365015      0.384833       19.015391
# min         3.800000          0.080000      0.000000        0.600000
# 25%         7.600000          0.430000      0.410000        9.800000
# 50%        10.000000          0.830000      0.870000       37.600000
# 75%        11.800000          1.080000      1.110000       46.800000
# max        15.900000          1.580000      1.660000       65.800000
#
#           chlorides  free_sulfur_dioxide  total_sulfur_dioxide       density  \
# count  21000.000000         21000.000000          21000.000000  21000.000000
# mean       0.200245           129.442333            229.008762      1.009972
# std        0.124933            77.167262            100.183265      0.012032
# ...

# %%
hd.rename(columns={'total_sulfur_dioxide':'total'})
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0               11.6             0.580         0.66            2.20
# 1               10.4             0.610         0.49            2.10
# 2                7.4             1.185         0.00            4.25
# 3               10.4             0.440         0.42            1.50
# 4                8.3             1.020         0.02            3.40
# ...              ...               ...          ...             ...
# 20995            9.7             1.020         0.91           50.00
# 20996           10.2             0.610         0.88           53.80
# 20997           13.4             0.460         1.04           52.10
# 20998            6.6             1.030         1.09           25.30
# 20999            9.3             0.930         1.32           33.60
#
#        chlorides  free_sulfur_dioxide  total  density    pH  sulphates  \
# 0          0.074                 10.0   47.0  1.00080  3.25       0.57
# ...

# %%
hd.mean()
# Out:
# fixed_acidity             9.797079
# volatile_acidity          0.774796
# citric_acid               0.793870
# residual_sugar           31.289348
# chlorides                 0.200245
# free_sulfur_dioxide     129.442333
# total_sulfur_dioxide    229.008762
# density                   1.009972
# pH                        3.158712
# sulphates                 1.020641
# alcohol                  11.291716
# quality                   6.000000
# dtype: float64

# %%
hd.std()
# Out:
# fixed_acidity             2.413919
# volatile_acidity          0.365015
# citric_acid               0.384833
# residual_sugar           19.015391
# chlorides                 0.124933
# free_sulfur_dioxide      77.167262
# total_sulfur_dioxide    100.183265
# density                   0.012032
# pH                        0.171371
# sulphates                 0.408304
# alcohol                   1.182198
# quality                   2.000048
# dtype: float64

# %%
hd.median()
# Out:
# fixed_acidity            10.0000
# volatile_acidity          0.8300
# citric_acid               0.8700
# residual_sugar           37.6000
# chlorides                 0.2050
# free_sulfur_dioxide     145.8000
# total_sulfur_dioxide    240.5000
# density                   1.0122
# pH                        3.1500
# sulphates                 1.0800
# alcohol                  11.3000
# quality                   6.0000
# dtype: float64

# %%
hd.mode()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            6.8              0.28          0.3             2.0      0.044
# 1            NaN               NaN          NaN             NaN        NaN
# 2            NaN               NaN          NaN             NaN        NaN
# 3            NaN               NaN          NaN             NaN        NaN
# 4            NaN               NaN          NaN             NaN        NaN
# 5            NaN               NaN          NaN             NaN        NaN
# 6            NaN               NaN          NaN             NaN        NaN
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 29.0                 111.0   0.9972  3.16        0.5
# 1                  NaN                   NaN   0.9976   NaN        NaN
# 2                  NaN                   NaN      NaN   NaN        NaN
# 3                  NaN                   NaN      NaN   NaN        NaN
# ...

# %%
hd['pH'].mean()
# Out:
# 3.1587119047619048

# %%
hd['pH'].mode()
# Out:
# 0    3.16
# Name: pH, dtype: float64

# %%
hd['pH'].median()
# Out:
# 3.15

# %%
hd['pH'].std()
# Out:
# 0.17137100174822836

# %%
hd.corr()
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000          0.562166     0.596388
# volatile_acidity           0.562166          1.000000     0.634551
# citric_acid                0.596388          0.634551     1.000000
# residual_sugar             0.653793          0.730159     0.765075
# chlorides                  0.601889          0.622915     0.660209
# free_sulfur_dioxide        0.653679          0.746446     0.700625
# total_sulfur_dioxide       0.506634          0.622015     0.636895
# density                    0.625238          0.673260     0.740276
# pH                        -0.254357         -0.213949    -0.185421
# sulphates                  0.579008          0.660118     0.645684
# alcohol                    0.167870          0.375957     0.358110
# quality                    0.037545          0.020286     0.052341
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# ...

# %%
hd.fillna(hd.mean())
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0               11.6             0.580         0.66            2.20
# 1               10.4             0.610         0.49            2.10
# 2                7.4             1.185         0.00            4.25
# 3               10.4             0.440         0.42            1.50
# 4                8.3             1.020         0.02            3.40
# ...              ...               ...          ...             ...
# 20995            9.7             1.020         0.91           50.00
# 20996           10.2             0.610         0.88           53.80
# 20997           13.4             0.460         1.04           52.10
# 20998            6.6             1.030         1.09           25.30
# 20999            9.3             0.930         1.32           33.60
#
#        chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# ...

# %%
hd.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0           11.6             0.580         0.66            2.20      0.074
# 1           10.4             0.610         0.49            2.10      0.200
# 2            7.4             1.185         0.00            4.25      0.097
# 3           10.4             0.440         0.42            1.50      0.145
# 4            8.3             1.020         0.02            3.40      0.084
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 10.0                  47.0  1.00080  3.25       0.57
# 1                  5.0                  16.0  0.99940  3.16       0.63
# 2                  5.0                  14.0  0.99660  3.63       0.54
# 3                 34.0                  48.0  0.99832  3.38       0.86
# 4                  6.0                  11.0  0.99892  3.48       0.49
#
#    alcohol  quality
# 0      9.0        3
# 1      8.4        3
# 2     10.7        3
# ...

# %%
hd.index
# Out:
# RangeIndex(start=0, stop=21000, step=1)

# %%
hd.T
# Out:
#                         0        1        2         3         4         5      \
# fixed_acidity         11.6000  10.4000   7.4000  10.40000   8.30000   7.60000
# volatile_acidity       0.5800   0.6100   1.1850   0.44000   1.02000   1.58000
# citric_acid            0.6600   0.4900   0.0000   0.42000   0.02000   0.00000
# residual_sugar         2.2000   2.1000   4.2500   1.50000   3.40000   2.10000
# chlorides              0.0740   0.2000   0.0970   0.14500   0.08400   0.13700
# free_sulfur_dioxide   10.0000   5.0000   5.0000  34.00000   6.00000   5.00000
# total_sulfur_dioxide  47.0000  16.0000  14.0000  48.00000  11.00000   9.00000
# density                1.0008   0.9994   0.9966   0.99832   0.99892   0.99476
# pH                     3.2500   3.1600   3.6300   3.38000   3.48000   3.50000
# sulphates              0.5700   0.6300   0.5400   0.86000   0.49000   0.40000
# alcohol                9.0000   8.4000  10.7000   9.90000  11.00000  10.90000
# ...
